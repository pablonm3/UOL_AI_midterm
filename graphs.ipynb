# %%
import pandas as pd

# %% [markdown]
# # tests

# %%
test = pd.read_csv("hyperparam_search/test.csv")
test2 = pd.read_csv("hyperparam_search/test2.csv")
test3 = pd.read_csv("hyperparam_search/test3.csv")

# %%
test.head()
# Out:
#    MEAN_FITNESS_DELTA  iterations
# 0            0.000000           1
# 1            0.194927           2
# 2            0.425204           3
# 3            0.670643           4
# 4            0.750361           5

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   MEAN_FITNESS_DELTA  20 non-null     float64
#  1   iterations          20 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 448.0 bytes

# %%
test.head(20)
# Out:
#     MEAN_FITNESS_DELTA  iterations
# 0             0.000000           1
# 1             0.194927           2
# 2             0.425204           3
# 3             0.670643           4
# 4             0.750361           5
# 5             0.553923           6
# 6             0.571234           7
# 7             0.257679           8
# 8             0.901565           9
# 9             0.635475          10
# 10            1.277316          11
# 11            0.549737          12
# 12            0.489978          13
# 13            0.695514          14
# 14            1.455518          15
# 15            0.515505          16
# 16            0.532756          17
# 17            0.688046          18
# 18            0.769669          19
# 19            0.265676          20

# %%
test.describe()
# Out:
#        MEAN_FITNESS_DELTA  iterations
# count           20.000000    20.00000
# mean             0.610036    10.50000
# std              0.337713     5.91608
# min              0.000000     1.00000
# 25%              0.473784     5.75000
# 50%              0.562579    10.50000
# 75%              0.709226    15.25000
# max              1.455518    20.00000

# %%
test2.head()
# Out:
#    MEAN_FITNESS_DELTA  pop_size  iterations
# 0            0.247293        10          10
# 1            0.526108        10          30
# 2            0.305350        50          10
# 3            0.340988        50          30

# %%
test3.head(30)
# Out:
#     EVOLUTION_SPEED  iterations
# 0          0.000000           1
# 1          0.005897           2
# 2          0.036282           3
# 3          0.046227           4
# 4          0.077962           5
# 5          0.104242           6
# 6          0.078802           7
# 7          0.084873           8
# 8          0.045764           9
# 9          0.039291          10
# 10         0.000000           1
# 11         0.032118           2
# 12         0.032320           3
# 13         0.023397           4
# 14         0.050343           5
# 15         0.046838           6
# 16         0.045563           7
# 17         0.030747           8
# 18         0.028049           9
# 19         0.026790          10
# 20         0.016186          11
# 21         0.009769          12
# 22         0.007857          13
# 23         0.033554          14
# 24         0.008101          15
# 25         0.012408          16
# 26         0.040818          17
# 27         0.005093          18
# 28         0.001180          19
# 29         0.022311          20

# %% [markdown]
# # Utility functions

# %% [markdown]
# # experiment: no_iterations

# %%
no_iterations = pd.read_csv("hyperparam_search/no_iterations.csv")
no_iterations.head(10)
# Out:
#    MEAN_FITNESS_DELTA  iterations
# 0            0.000000           1
# 1           -0.065829           2
# 2            0.116504           3
# 3            0.133765           4
# 4            0.067644           5
# 5            0.314348           6
# 6            0.438543           7
# 7            0.185812           8
# 8            0.701158           9
# 9            0.235607          10

# %% [markdown]
# # Plots

# %%
def plot(df, ax, x_name, y_name, z_filter_key=None, z_filter_value=None):
    if(z_filter_key):
        df = df[df[z_filter_key] == z_filter_value]
    x = df[x_name]
    y = df[y_name]
    ax.scatter(x, y)
    if(z_filter_key):
        ax.set_title(f"{z_filter_key} = {z_filter_value}")

# %% [markdown]
# # number of iterations

# %%
no_iterations = pd.read_csv("hyperparam_search/no_iterations.csv")
no_iterations.head()
# Out:
#    MEAN_FITNESS_DELTA  iterations
# 0            0.000000           1
# 1           -0.065829           2
# 2            0.116504           3
# 3            0.133765           4
# 4            0.067644           5

# %%
import numpy as np
import matplotlib.pyplot as plt
fig, axis = plt.subplots(1, figsize=(20, 15))
plt.ylabel('MEAN_FITNESS_DELTA')
plt.xlabel('iterations')
plot(no_iterations, axis, "iterations", "MEAN_FITNESS_DELTA")
fig.tight_layout()
plt.show()

# %%
no_iterations2 = pd.read_csv("hyperparam_search/no_iterations2.csv")
no_iterations2.head()
# Out:
#    EVOLUTION_SPEED  iterations
# 0         0.005824         100
# 1         0.008010         300
# 2         0.001529         500
# 3         0.002044        1000
# 4         0.000841        1500

# %%
fig, axis = plt.subplots(1, figsize=(8, 4))
plt.ylabel('EVOLUTION_SPEED')
plt.xlabel('iterations')
plot(no_iterations2, axis, "iterations", "EVOLUTION_SPEED")
fig.tight_layout()
plt.show()

# %% [markdown]
# # Population size

# %%
pop_size = pd.read_csv("hyperparam_search/pop_size.csv")
pop_size.head()
# Out:
#    MEAN_FITNESS_DELTA  pop_size  iterations
# 0            0.151221        10         100
# 1            1.519584        10         300
# 2            1.197141        10         500
# 3            0.768303        10        1000
# 4            0.722548        15         100

# %%
fig, axis = plt.subplots(4, sharex=True, sharey=True, figsize=(6, 12))
plt.ylabel('MEAN_FITNESS_DELTA')
plt.xlabel('pop_size')
i=0
for it in [100, 300, 500, 1000]:
    plot(pop_size, axis[i], "pop_size", "MEAN_FITNESS_DELTA", "iterations", it)
    i += 1
fig.tight_layout()
plt.show()

# %%
pop_size2 = pd.read_csv("hyperparam_search/pop_size2.csv")
pop_size2.head()
# Out:
#    EVOLUTION_SPEED  pop_size
# 0         0.043290        10
# 1         0.001109        20
# 2         0.013373        30
# 3         0.046590        40
# 4         0.032931        50

# %%
fig, axis = plt.subplots(1, figsize=(6, 4))
plt.ylabel('EVOLUTION_SPEED')
plt.xlabel('pop_size')
plot(pop_size2, axis, "pop_size", "EVOLUTION_SPEED")

fig.tight_layout()
plt.show()

# %% [markdown]
# # Pool size

# %%
pool_size = pd.read_csv("hyperparam_search/pool_size.csv")
pool_size.head()
# Out:
#    MEAN_FITNESS_DELTA  iterations  pool_size
# 0            0.764406         100          1
# 1            0.041812         100          4
# 2            0.339733         100          8
# 3            0.520297         150          1
# 4            1.220702         150          4

# %%
fig, axis = plt.subplots(3, sharex=True, sharey=True, figsize=(6, 12))
plt.ylabel('MEAN_FITNESS_DELTA')
plt.xlabel('iterations')
i=0
for it in [1,4,8]:
    plot(pool_size, axis[i], "iterations", "MEAN_FITNESS_DELTA", "pool_size", it)
    i += 1
fig.tight_layout()
plt.show()

# %%
pool_size2 = pd.read_csv("hyperparam_search/pool_size2.csv")
pool_size2.head()
# Out:
#    EVOLUTION_SPEED  pool_size
# 0         0.001427          1
# 1         0.001047          2
# 2         0.056198          4
# 3         0.000916          8

# %%
fig, axis = plt.subplots(1, figsize=(6, 4))
plt.ylabel('EVOLUTION_SPEED')
plt.xlabel('pool_size')
plot(pool_size2, axis, "pool_size", "EVOLUTION_SPEED")

fig.tight_layout()
plt.show()

# %% [markdown]
# # Initial gene count

# %%
init_gene_count = pd.read_csv("hyperparam_search/init_gene_count.csv")
init_gene_count.head()
# Out:
#    MEAN_FITNESS_DELTA  init_gene_count
# 0            0.818697                1
# 1            2.646893                3
# 2            1.096454                5
# 3            0.642989                6
# 4            1.311929                8

# %%
fig, axis = plt.subplots(1, figsize=(6,4))
plt.ylabel('MEAN_FITNESS_DELTA')
plt.xlabel('init_gene_count')
plot(init_gene_count, axis, "init_gene_count", "MEAN_FITNESS_DELTA")

fig.tight_layout()
plt.show()

# %%
init_gene_count2 = pd.read_csv("hyperparam_search/init_gene_count2.csv")
init_gene_count2.head()
# Out:
#    EVOLUTION_SPEED  init_gene_count
# 0         0.001097                1
# 1         0.000557                3
# 2         0.000782                5
# 3         0.001677                6
# 4         0.002020                8

# %%
fig, axis = plt.subplots(1, figsize=(6, 4))
plt.ylabel('EVOLUTION_SPEED')
plt.xlabel('init_gene_count')
plot(init_gene_count2, axis, "init_gene_count", "EVOLUTION_SPEED")

fig.tight_layout()
plt.show()

# %% [markdown]
# # Mutation rate

# %%
mutation_rate = pd.read_csv("hyperparam_search/mutation_rate.csv")
mutation_rate.head()
# Out:
#    MEAN_FITNESS_DELTA  mutation_rate
# 0            2.030535            0.1
# 1            0.600800            0.2
# 2            0.412513            0.3
# 3            0.222813            0.4
# 4           17.421099            0.5

# %%
fig, axis = plt.subplots(1, figsize=(6, 4))
plt.ylabel('MEAN_FITNESS_DELTA')
plt.xlabel('mutation_rate')
plot(mutation_rate, axis, "mutation_rate", "MEAN_FITNESS_DELTA")

fig.tight_layout()
plt.show()

# %% [markdown]
# # Mutation rate

# %%
mutation_rate2 = pd.read_csv("hyperparam_search/mutation_rate2.csv")
mutation_rate2.head()
# Out:
#    EVOLUTION_SPEED  mutation_rate
# 0         0.001059            0.1
# 1         0.000629            0.2
# 2         0.000806            0.3
# 3         0.000840            0.4
# 4         0.000889            0.5

# %%
fig, axis = plt.subplots(1, figsize=(6, 4))
plt.ylabel('EVOLUTION_SPEED')
plt.xlabel('mutation_rate')
plot(mutation_rate2, axis, "mutation_rate", "EVOLUTION_SPEED")

fig.tight_layout()
plt.show()

# %% [markdown]
# # Plots for encoding scheme changes

# %% [markdown]
# ## Link length longer

# %%
link_len_longer1 = pd.read_csv("hyperparam_search_gene_spec/link-length-longer1.csv")
print(np.mean(link_len_longer1["MEAN_FITNESS_DELTA"]))
link_len_longer1.head(5)
# Out:
# 1.402721478374991
#    MEAN_FITNESS_DELTA  iterations
# 0            0.000000           1
# 1            0.548449           2
# 2            0.596881           3
# 3            0.526594           4
# 4            1.048134           5

# %%
fig, axis = plt.subplots(1, figsize=(10, 6))
plt.ylabel('MEAN_FITNESS_DELTA')
plt.xlabel('iterations')
plot(link_len_longer1, axis, "iterations", "MEAN_FITNESS_DELTA")
fig.tight_layout()
plt.show()

# %%
link_len_longer2 = pd.read_csv("hyperparam_search_gene_spec/link-length-longer2.csv")
print(np.mean(link_len_longer2["MEAN_FITNESS_DELTA"]))
# Out:
# 1.5245531039858742

# %%
fig, axis = plt.subplots(1, figsize=(10, 6))
plt.ylabel('MEAN_FITNESS_DELTA')
plt.xlabel('iterations')
plot(link_len_longer2, axis, "iterations", "MEAN_FITNESS_DELTA")
fig.tight_layout()
plt.show()

# %% [markdown]
# ### Link length shorter

# %%
link_len_shorter1 = pd.read_csv("hyperparam_search_gene_spec/link-length-shorter1.csv")
print(np.mean(link_len_shorter1["MEAN_FITNESS_DELTA"]))
# Out:
# 1.2119782283751124

# %%
fig, axis = plt.subplots(1, figsize=(10, 6))
plt.ylabel('MEAN_FITNESS_DELTA')
plt.xlabel('iterations')
plot(link_len_shorter1, axis, "iterations", "MEAN_FITNESS_DELTA")
fig.tight_layout()
plt.show()

# %%
link_len_shorter2 = pd.read_csv("hyperparam_search_gene_spec/link-length-shorter2.csv")
print(np.mean(link_len_shorter2["MEAN_FITNESS_DELTA"]))
# Out:
# 1.1952381791699502

# %%
fig, axis = plt.subplots(1, figsize=(10, 6))
plt.ylabel('MEAN_FITNESS_DELTA')
plt.xlabel('iterations')
plot(link_len_shorter2, axis, "iterations", "MEAN_FITNESS_DELTA")
fig.tight_layout()
plt.show()

# %% [markdown]
# ## Link mass lighter

# %%
link_mass_lighter1 = pd.read_csv("hyperparam_search_gene_spec/link-mass-lighter1.csv")
print(np.mean(link_mass_lighter1["MEAN_FITNESS_DELTA"]))
# Out:
# 1.1285589334616193

# %%
fig, axis = plt.subplots(1, figsize=(10, 6))
plt.ylabel('MEAN_FITNESS_DELTA')
plt.xlabel('iterations')
plot(link_mass_lighter1, axis, "iterations", "MEAN_FITNESS_DELTA")
fig.tight_layout()
plt.show()

# %%
link_mass_lighter2 = pd.read_csv("hyperparam_search_gene_spec/link-mass-lighter2.csv")
print(np.mean(link_mass_lighter2["MEAN_FITNESS_DELTA"]))
# Out:
# 5.6145647639870715

# %%
fig, axis = plt.subplots(1, figsize=(10, 6))
plt.ylabel('MEAN_FITNESS_DELTA')
plt.xlabel('iterations')
plot(link_mass_lighter2, axis, "iterations", "MEAN_FITNESS_DELTA")
fig.tight_layout()
plt.show()

# %% [markdown]
# ## Link mass heavier

# %%
link_mass_heavier1 = pd.read_csv("hyperparam_search_gene_spec/link-mass-heavier1.csv")
print(np.mean(link_mass_heavier1["MEAN_FITNESS_DELTA"]))
# Out:
# 1.7498869381444402

# %%
fig, axis = plt.subplots(1, figsize=(10, 6))
plt.ylabel('MEAN_FITNESS_DELTA')
plt.xlabel('iterations')
plot(link_mass_heavier1, axis, "iterations", "MEAN_FITNESS_DELTA")
fig.tight_layout()
plt.show()

# %%
link_mass_heavier2 = pd.read_csv("hyperparam_search_gene_spec/link-mass-heavier2.csv")
print(np.mean(link_mass_heavier2["MEAN_FITNESS_DELTA"]))
# Out:
# 0.7013816538842348

# %%
fig, axis = plt.subplots(1, figsize=(10, 6))
plt.ylabel('MEAN_FITNESS_DELTA')
plt.xlabel('iterations')
plot(link_mass_heavier2, axis, "iterations", "MEAN_FITNESS_DELTA")
fig.tight_layout()
plt.show()

# %% [markdown]
# ## Link recurrence higher

# %%
link_recurrence_higher1 = pd.read_csv("hyperparam_search_gene_spec/link-recurrence-higher1.csv")
print(np.mean(link_recurrence_higher1["MEAN_FITNESS_DELTA"]))
# Out:
# 0.6938593840921367

# %%
fig, axis = plt.subplots(1, figsize=(10, 6))
plt.ylabel('MEAN_FITNESS_DELTA')
plt.xlabel('iterations')
plot(link_recurrence_higher1, axis, "iterations", "MEAN_FITNESS_DELTA")
fig.tight_layout()
plt.show()

# %%
link_recurrence_higher2 = pd.read_csv("hyperparam_search_gene_spec/link-recurrence-higher2.csv")
print(np.mean(link_recurrence_higher2["MEAN_FITNESS_DELTA"]))
# Out:
# 1.1115354143553136

# %%
fig, axis = plt.subplots(1, figsize=(10, 6))
plt.ylabel('MEAN_FITNESS_DELTA')
plt.xlabel('iterations')
plot(link_recurrence_higher2, axis, "iterations", "MEAN_FITNESS_DELTA")
fig.tight_layout()
plt.show()

# %% [markdown]
# ## Baseline

# %%
baseline = pd.read_csv("hyperparam_search_gene_spec/baseline.csv")
print(np.mean(baseline["MEAN_FITNESS_DELTA"]))
# Out:
# 1.0917234638181252

# %%
fig, axis = plt.subplots(1, figsize=(10, 6))
plt.ylabel('MEAN_FITNESS_DELTA')
plt.xlabel('iterations')
plot(baseline, axis, "iterations", "MEAN_FITNESS_DELTA")
fig.tight_layout()
plt.show()
